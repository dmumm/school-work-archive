# %%
#run your program using
#tot = 10000000
#min = 0
#max = 20

#save results with this script

list1 = open('results_binary.txt', 'r').read().split(" ")
list1.remove('')
results_binary = [ float(val) for val in list1]

list2 = open('results_splay.txt', 'r').read().split(" ")
list2.remove("")
results_splay = [ float(val) for val in list2]

# %%
#run your program using
#tot = 10000000
#min = 0
#max = 100000

#save results with this script

list3 = open('results_binary.txt', 'r').read().split(" ")
list3.remove('')
results_binary_after = [ float(val) for val in list3]

list4 = open('results_splay.txt', 'r').read().split(" ")
list4.remove("")
results_splay_after = [ float(val) for val in list4]

# %%
#plot everything together

import matplotlib.pyplot as plt
# %matplotlib inline  

plt.plot(results_binary)
plt.plot(results_splay)

plt.plot(results_binary_after)
plt.plot(results_splay_after)

# %%
#compare results for the binary tree

plt.plot(results_binary)
plt.plot(results_binary_after)

# %%
#compare results for the Splay tree

plt.plot(results_splay)
plt.plot(results_splay_after)
